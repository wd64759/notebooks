# %%
# %pylab inline
# %load a.py
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sdat = sinc(arange(7))
plot(sdat)

# %%
import scipy

# %%
from PIL import Image, ImageFilter

# %%
img = Image.open(r'D:\doc\baby.jpg')

plt.subplot(111)
img_n = img.filter(ImageFilter.GaussianBlur)
plt.axis('off')
plt.imshow(img_n)

# %%
np.testing.assert_

# %%
import sqlite3

# %%
from pandas import Series, DataFrame

# %%
s = Series([1,2,3,5,6,7], index=['a','b','c','d','e','f'])

# %%
t = Series({10:'a', 20:'b'})

# %%
data = {'r1':randn(3).tolist(), 'r2':randn(3).tolist()}
# Out:
# {'k1': array([0, 1, 2]), 'k2': array([[-1.3290645 ,  0.81903051, -1.10434992],
#         [-0.75699012, -2.53090339, -0.97816811],
#         [-0.15608368,  1.0234291 ,  0.92865664],
#         [-0.59286208, -0.27082317,  0.10354014],
#         [-0.10266631, -1.1905603 ,  0.59005202],
#         [-0.21371852,  0.09557452, -0.32363535]])}

# %%
df = DataFrame(data)
df2 = DataFrame(df.T, columns= [2,1,0])
df2
# Out:
#            2         1         0
# r1  0.281126  0.733274 -0.843697
# r2  1.187170 -1.008764  0.381636

# %%
del df2[0]

# %%
df2[2]
# Out:
# r1    0.281126
# r2    1.187170
# Name: 2, dtype: float64
